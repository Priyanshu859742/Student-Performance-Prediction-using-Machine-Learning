# %% [markdown]
# # Exploratory Data Analysis and Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Load dataset
data_path = os.path.join('..', 'data', 'student_performance.csv')
df = pd.read_csv(data_path)
df.head()
# Out:
#    Study_Hours  Attendance_Percentage  Previous_Marks  Assignments_Completed  \
# 0         4.37                  59.26           55.70                      2
# 1         9.56                  77.10           54.82                      8
# 2         7.59                  93.65           94.38                      4
# 3         6.39                  86.61           54.97                      7
# 4         2.40                  90.33           56.32                      6
#
#    Final_Score  Pass_Fail
# 0        38.74          0
# 1        80.49          1
# 2        78.67          1
# 3        62.60          1
# 4        58.65          1

# %% [markdown]
# ## Data Understanding

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Study_Hours            1000 non-null   float64
#  1   Attendance_Percentage  1000 non-null   float64
#  2   Previous_Marks         1000 non-null   float64
#  3   Assignments_Completed  1000 non-null   int64
#  4   Final_Score            1000 non-null   float64
#  5   Pass_Fail              1000 non-null   int64
# dtypes: float64(4), int64(2)
# memory usage: 47.0 KB
#        Study_Hours  Attendance_Percentage  Previous_Marks  \
# count  1000.000000             1000.00000     1000.000000
# mean      5.412390               75.35080       70.144430
# std       2.629218               14.60942       17.440554
# min       1.040000               50.16000       40.000000
# 25%       3.127500               62.05250       55.680000
# 50%       5.475000               75.93500       70.040000
# 75%       7.702500               88.02000       85.545000
# max      10.000000               99.97000       99.870000
#
#        Assignments_Completed  Final_Score    Pass_Fail
# count            1000.000000  1000.000000  1000.000000
# mean                5.084000    59.705150     0.772000
# std                 3.202687    12.374528     0.419753
# min                 0.000000    20.480000     0.000000
# 25%                 2.000000    50.755000     1.000000
# 50%                 5.000000    59.715000     1.000000
# 75%                 8.000000    68.640000     1.000000
# max                10.000000    97.370000     1.000000

# %% [markdown]
# ## Correlation Analysis

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Feature Correlation Matrix')
plt.show()

# %% [markdown]
# ## Visualizing Targets

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(df['Final_Score'], bins=20, kde=True)
plt.title('Distribution of Final Score')

plt.subplot(1, 2, 2)
sns.countplot(x='Pass_Fail', data=df)
plt.title('Pass vs Fail Count')
plt.show()
